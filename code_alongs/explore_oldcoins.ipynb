# %% [markdown]
# ### Exploring the module oldcoin

# %%
from oldcoins import OldCoinsStash

# %%
stash_ragner = OldCoinsStash("Ragnar Lothbroke")

stash_ragner.deposit(100, 100)

stash_ragner.check_balance()

stash_ragner.withdraw(10,10)

stash_ragner.check_balance()
# Out:
# 'Coins in stash: 90 riksdaler, 90 skilling'

# %%
stash_bjorn = OldCoinsStash("Bjorn")

stash_bjorn
# Out:
# OldCoinStash(owner='Bjorn')
