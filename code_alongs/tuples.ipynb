# %% [markdown]
# #### Lecture 6b - Tuples
# - less flexible than list
# - better performance in list

# %% [markdown]
# ##### create a tuple

# %%
fruits = ("apple", "orange", "strawberry")

# %% [markdown]
# ##### Access an item (indexing)

# %%
fruits
# Out:
# ('apple', 'orange', 'strawberry')

# %% [markdown]
# ##### Accessing multiple items (slicing)

# %%
fruits[0:2]
# Out:
# ('apple', 'orange')
