# %% [markdown]
# # Lecture 5c - for loop
# - loop through the same block of codes for several times
# - number of looping is known

# %%
# a simple example
for i in range(5): # range(n) returns numbers from 0 to n-1
    print(i)
# Out:
# 0
# 1
# 2
# 3
# 4

# %% [markdown]
# #### range() function
# - with only one argument, like range(5), end argument
# - with three arguments , like range(1,5,5), start, end, number of step

# %%
# we want to change the default setting of print() function to not start a newline

for i in range(1,5,2):
    print(i, end= " ")
# Out:
# 1 3

# %% [markdown]
# Random module

# %%
import random as rnd

# %%
#. generate a dice result from on throw
dice_result = rnd.randint(1,6) # use the alias. when you want to use this function.
dice_result
# Out:
# 3

# %% [markdown]
# loop through a list

# %%
# list is a collection of items/values/data

fruits = ["apple", "orange", "grape"]

for fruit in fruits: # fruits refer to a specific list, fruit is an intermediate variable.
    print(f"I love to eat {fruit}")
# Out:
# I love to eat apple
# I love to eat orange
# I love to eat grape

# %% [markdown]
# ##### Example of pythonic code
# - a classic example when writing a for loop with index
# - problem to solve: loop through the fruits list and also print out the index for each fruit

# %%
# with enumerate

for i, fruit in enumerate(fruits,1):
    print(f"{i}. {fruit}")
# Out:
# 1. apple
# 2. orange
# 3. grape

# %%
# without enumerate

i = 1

for fruit in fruits:
    print(f"{i}. {fruit}")
    i += 1
# Out:
# 1. apple
# 2. orange
# 3. grape
