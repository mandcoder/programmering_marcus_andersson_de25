# %% [markdown]
# # Lecture 4 - input, output & variables

# %% [markdown]
# ### Print statement

# %% [markdown]
# To print out string

# %%
# you can use hashtag to comment out lines of codes
# use the print statement to print out string

# f-string is used to combine variables and string together

name = "Mack"

print(f"Hello {name}")
# Out:
# Hello Mack

# %% [markdown]
# To print out string and variables

# %% [markdown]
# ### Variables
#
# - you can store different types of data in variables --> assigning value to variable
# - we can use the data by refering to the variable instead
# - in lecture 4, we are see variables storing on value, even though the value can be of different types
# - in lecture 6, we will see that we can store a collection of values

# %% [markdown]
# create variables with different data types

# %%
# string

first_name = "Dexter"

# numeric 

height = 2.0

# float, number with decimals

exact_height = 1.9856567

age = 24

# %% [markdown]
# print out a message using all these variables with different data types

# %%
print(f"The star is {first_name} and his height is {height}m,\nactually his exact height is {exact_height}m")
# Out:
# The star is Dexter and his height is 2.0m,
# actually his exact height is 1.98m

# %% [markdown]
# #### format in f-string
# - is how you display current value, its not change the actual value

# %%
#.1f means after the integer, keep one decimal place
print(f"the exact height is {exact_height:.3f}cm")
# Out:
# the exact height is 1.986cm

# %% [markdown]
# ### boolean (bool)

# %%
# str
name = "Kokchun"

# int 
height = 200

# float

exact_height = 199

# bool

is_teacher = True # alternative, can False for boolean value.

# %%
# check datatype
type(is_teacher)
# Out:
# bool

# %% [markdown]
# ## input from users
# - how to code so that the value of the variable is decided after i run the code?

# %%
# create a name variabel, asking for user input

name = input()

# %%
# print out a f-string

print(f"Hello {name}")
# Out:
# Hello kalle

# %%
# check the value

type(name)
# Out:
# str

# %%
age = input("Whats your age")

# %% [markdown]
# ### Type coercsion
# - converting data types from on to another
# - apllies on variable in general, not just when using input() function

# %%
# double check the data type for the existing age variable
print(type(age)) # as by deafult, .ipynb file cell only shows output from the last line code.
age
# Out:
# <class 'str'>
# '45'

# %%
# convert to int and create a new variable for this
age_int = int(age)

type(age_int)
# Out:
# int

# %%
# convert and overwrite the existing value

age = int(age)
type(age)
# Out:
# int
