# %% [markdown]
# # Lecture 6a - List
# - one of the collection data type/iterables
# - used for storing several items in a variable
# - for collection data type, we will be learning:
#
#     - characteristics
#     - available operations

# %%
tv_shows = ["Antikrundan", "Masterchiefs", "Aktuellt", "Talang"]

# %% [markdown]
# ##### Access an item (Indexing)
#
# - index begins with 0
# - use [] to access an item with a certain index
# - by default, the first item begins from the left

# %%
# to access the second item

tv_shows[1]
# Out:
# 'Masterchief'

# %%
# to acces the last item

last_index = len(tv_shows)-1

tv_shows[last_index]
# Out:
# 'Talan'

# %%
# to access the last item - by counting from the left

tv_shows[-1]
# Out:
# 'Talang'

# %% [markdown]
# #### Iterate through a list

# %%
for tv_show in tv_shows:
    print(tv_show)
# Out:
# Solsidan
# Masterchiefs
# Aktuellt
# Talang

# %% [markdown]
# #### change a value of a list item

# %%
tv_shows[0] = "Solsidan"
tv_shows
# Out:
# ['Solsidan', 'Masterchiefs', 'Aktuellt', 'Talang']

# %% [markdown]
# ##### Append new value to a list
#
# - add a new item as the last item

# %%
# tv_shovs is a list, with an method called append()

tv_shows.append("Robinson")
tv_shows
# Out:
# ['Solsidan', 'Masterchiefs', 'Aktuellt', 'Talang', 'Robinson', 'Robinson']

# %% [markdown]
# ##### Access multiple items (Slicing)
# - make using of slicing operator

# %%
# closing boundary on the left and opening boundary on the right
# from the item with index 0 inclusive up to item with index (2-1)

tv_shows[0:2]
# Out:
# ['Solsidan', 'Masterchiefs']

# %% [markdown]
# ##### Sort a list

# %%
tv_shows.sort() # by default, the list will be sorted by ascending order (either alphabetically or numerically)
tv_shows
# Out:
# ['Aktuellt', 'Masterchiefs', 'Robinson', 'Robinson', 'Solsidan', 'Talang']

# %%
tv_shows.sort(reverse=True)

tv_shows
# Out:
# ['Talang', 'Solsidan', 'Robinson', 'Robinson', 'Masterchiefs', 'Aktuellt']

# %%
tv_shows[0]
# Out:
# 'Talang'

# %% [markdown]
# ##### Create a list by list-comprehension
# - clean code to create when creating a list from another iterable

# %%
# the value for each item in the list cubes is actually a calculation from items in an existing iterable (i.e range())
cubes = [x**3 for x in range(1,10)]
cubes
# Out:
# [1, 8, 27, 64, 125, 216, 343, 512, 729]
