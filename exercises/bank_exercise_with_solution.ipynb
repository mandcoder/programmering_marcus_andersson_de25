# %% [markdown]
# # 🏦 Python OOP Exercise: Bank Class for Customer Account Management
# ### Version: With Solution
# Based on [w3resource Python OOP Exercise 11](https://www.w3resource.com/python-exercises/oop/python-oop-exercise-11.php)
#
# #### 🎯 Objective
# Create a Python class `Bank` that manages customer accounts and supports deposit, withdrawal, and balance check.

# %%
class Bank:
    def __init__(self, account_number, name, balance=0):
        self.account_number = account_number
        self.name = name
        self.balance = balance

    def deposit(self, amount):
        if amount > 0:
            self.balance += amount
            print(f"Deposited {amount} SEK to {self.name}'s account.")
        else:
            print("Deposit amount must be positive.")

    def withdraw(self, amount):
        if amount <= 0:
            print("Withdrawal amount must be positive.")
        elif amount > self.balance:
            print("Insufficient funds.")
        else:
            self.balance -= amount
            print(f"Withdrawn {amount} SEK from {self.name}'s account.")

    def get_balance(self):
        return f"Current balance for {self.name}: {self.balance} SEK"

    def __str__(self):
        return f"BankAccount({self.account_number}, {self.name}, Balance: {self.balance} SEK)"

# %%
# ✅ Test the class
customer1 = Bank(101, 'Anna', 5000)
customer2 = Bank(102, 'Marcus', 8000)

customer1.deposit(1500)
customer1.withdraw(2000)

print(customer1.get_balance())
print(customer2.get_balance())

print(customer1)
print(customer2)

# %% [markdown]
# #### 💡 Extension Ideas
# - Add interest calculation method.
# - Add transaction history list.
# - Add transfer between accounts.
# - Protect attributes using encapsulation (`_balance` or `__balance`).
