# %% [markdown]
# # 🏦 Python OOP Exercise: Bank Class for Customer Account Management
# ### Version: No Solution
# This exercise is inspired by w3resource.com.
#
# #### 🎯 Objective
# Create a Python class named `Bank` to manage customer accounts.
# The class should allow customers to:
# - Open a new account
# - Deposit money
# - Withdraw money
# - Check account balance
#
# #### 🧩 Requirements
# 1. Use OOP principles (class, methods, instance attributes).
# 2. Implement validation (e.g., prevent withdrawing more than available balance).
# 3. Use `__str__()` or `__repr__()` for a readable representation.
#
# #### ✍️ Task
# - Create the `Bank` class and its methods.
# - Create at least two customer objects and simulate deposits and withdrawals.
#
# #### 💡 Hint
# Start by defining `__init__()` with attributes like `account_number`, `name`, and `balance`.
# Then define methods: `deposit()`, `withdraw()`, and `get_balance()`.
