# %% [markdown]
# # 🐞 OOP Debug Exercise: Person class
# I denna övning ska du **felsöka** en klass som använder `@property` och `@setter`.
#
# Målet är att upptäcka vanliga misstag när man implementerar getter/setter-logik i Python.

# %% [markdown]
# ## 🔍 Uppgift
# Du får här en felaktig version av `Person`-klassen. Läs igenom den noggrant och försök identifiera vad som är fel.
#
# ### Din uppgift:
# 1. Kör koden och observera vad som händer.
# 2. Förklara (i kommentar) **vad som är fel** och **varför**.
# 3. Skriv en **korrigerad version** av klassen som fungerar som tänkt.
# 4. Testa den genom att skapa ett objekt och ändra ålder till både giltiga och ogiltiga värden.

# %%
# ❌ Den här versionen innehåller fel – ändra inget här än.
class Person:

    def __init__(self, name, age):
        self.name = name
        self._age = age

    @property
    def age(self):
        print("Getter Called")
        return self._age
        
    @age.setter
    def age(self, age):
        if not ( 0>= age <=124):
            print("Age must be between 0 and 124")
        else:
            self._age = self.age

person1 = Person("Anna", 45)
person1.age = -6

# %% [markdown]
# ## 🧠 Din uppgift – rätta koden
# Skriv nu en fungerande version av `Person`-klassen nedan.
# Använd gärna utskrifter (`print()`) i `getter` och `setter` för att se när de anropas.

# %%
# YOUR FIXED VERSION HERE

# %% [markdown]
# ## 🧪 Testa din kod
# Skapa ett `Person`-objekt, ändra ålder flera gånger och testa både giltiga och ogiltiga värden.

# %%
# YOUR TESTS HERE

# %% [markdown]
# ---
# 💡 **Tips:**
# - Kontrollera logiska operatorer i din `if`-sats.
# - Se upp för att anropa en property inifrån sin egen setter – det leder till rekursion.
# - Jämför din kod med vad du vet om inkapsling (`encapsulation`).
