# %% [markdown]
# # 🎰 Svenska Spel AB – OOP Övning
# I denna övning ska du träna på objektorienterad programmering (OOP) i Python.
#
# Fokus ligger på:
# - att skapa en **klass**
# - använda **@property** och **setter**
# - implementera **__repr__** och **__str__**
# - skapa objekt och testa metoderna
#
# Temat är **Svenska Spel AB** – du ska representera en *lotteribiljett*.

# %% [markdown]
# ## 🧩 Steg 1 – Skapa klassen `LotteryTicket`
# Skapa en klass som heter `LotteryTicket` med följande attribut:
#
# | Attribut | Typ | Beskrivning |
# |-----------|-----|-------------|
# | `ticket_id` | str | Biljettens unika ID, t.ex. `"SS-2025-001"` |
# | `game_type` | str | Typ av spel, t.ex. `"Lotto"`, `"Triss"`, `"Keno"` |
# | `owner` | str | Namn på den som äger biljetten |
# | `__amount_won` | int | (privat) summan som biljetten har vunnit, i SEK |
#
# Skapa en konstruktor (`__init__`) som tar dessa värden som argument.

# %% [markdown]
# - Skapa en **property** för `amount_won` som returnerar det privata attributet `__amount_won`.
# - Lägg till en **setter** som:
#   - inte tillåter negativa värden,
#   - och skriver ut ett felmeddelande om någon försöker sätta ett negativt belopp.

# %% [markdown]
# Skapa en metod `check_win()` som returnerar en text beroende på om vinsten är större än 0 eller inte.
#
# Exempel:
# - `"Grattis! Du vann {self.amount_won} SEK!"`
# - `"Tyvärr ingen vinst denna gång."`

# %% [markdown]
# Skriv `__repr__` och `__str__`
# - `__repr__` ska returnera en teknisk representation av objektet, t.ex.:
#   `LotteryTicket(ticket_id='SS-2025-001', game_type='Lotto', owner='Anna', amount_won=1000)`
# - `__str__` ska returnera en mer användarvänlig text, t.ex.:
#   `Biljett SS-2025-001 – Lotto för Anna (vinst: 1000 SEK)`

# %%
# YOUR CODE HERE

# %% [markdown]
# Testa din klass
# Skapa några objekt och testa din klass.
#
# Exempel:
# ```python
# t1 = LotteryTicket("SS-2025-001", "Lotto", "Anna", 0)
# t2 = LotteryTicket("SS-2025-002", "Triss", "Erik", 100000)
# t3 = LotteryTicket("SS-2025-003", "Keno", "Sara", -500)
#
# print(t1)
# print(t2.check_win())
# print(repr(t2))
# t3.amount_won = 5000
# print(t3.amount_won)
# ```

# %%
# YOUR CODE HERE
