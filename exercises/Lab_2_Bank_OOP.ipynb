# %% [markdown]
# # Lab 3 – Bank OOP
#
# This notebook is for manual testing of your classes.
#
# Do not include solutions if this is the student version.

# %% [markdown]
# ## account.py

# %%
class Account:
    def __init__(self, account_number: str, balance: float, owner):
        # YOUR CODE HERE
        pass

# %% [markdown]
# ## savings_account.py

# %%
class SavingsAccount(Account):
    def __init__(self, account_number: str, balance: float, owner, interest_rate: float):
        # YOUR CODE HERE
        pass

# %% [markdown]
# ## customer.py

# %%
class Customer:
    def __init__(self, personal_number: str, name: str):
        # YOUR CODE HERE
        pass

# %% [markdown]
# ## bank.py (BONUS)

# %%
class Bank:
    def __init__(self, name: str):
        # YOUR CODE HERE
        pass

# %% [markdown]
# ## Manual Test Examples

# %%
# Example:
# from account import Account
# from savings_account import SavingsAccount
# from customer import Customer
# acc = Account('1001-111', 5000, 'Anna')
# print(acc)
