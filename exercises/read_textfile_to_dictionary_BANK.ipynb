# %% [markdown]
# # 🏦 Övning: Läs in bankdata och bygg en kund-dictionary
#
# ## 🎯 Mål
# Du ska läsa in en textfil som innehåller kundinformation och bygga en dictionary med kontonummer som nyckel.
#
# Du övar på att:
# - Läsa in en textfil med `open()`
# - Använda `split()` för att dela upp varje rad
# - Bygga en dictionary dynamiskt
# - Hantera fel med `try` / `except FileNotFoundError`
#
# ---
#
# ## 🧾 Fil: `bank_customers.txt`
# Skapa först en textfil i din mapp, t.ex.
# `data_playground/raw_data/bank_customers.txt`
#
# **Innehåll:**
# ```
# Alice Johnson,SE123456789,15000
# Bob Smith,SE987654321,22000
# Carol Andersson,SE555666777,9000
# David Eriksson,SE444333222,18500
# Emma Lind,SE222111000,30500
# ```
#
# ---

# %% [markdown]
# ## 🧩 Steg 1: Läs in filen och bygg dictionaryn
#
# Skapa en dictionary där varje kontonummer (`account_number`) är nyckeln och värdet är en inre dictionary med `name` och `balance`.

# %%
# 👉 Write your code here

# Tips:
# - Skapa en tom dictionary, t.ex. customers = {}
# - Läs in filen med open("bank_customers.txt", "r")
# - Loopa igenom varje rad och använd split(',')
# - Använd try / except FileNotFoundError för att hantera om filen saknas

# %% [markdown]
# ## ✅ Steg 2: Testa resultatet
#
# Skriv ut dictionaryn och kontrollera att strukturen ser ut så här:
#
# ```python
# {
#   'SE123456789': {'name': 'Alice Johnson', 'balance': '15000'},
#   'SE987654321': {'name': 'Bob Smith', 'balance': '22000'},
#   ...
# }
# ```

# %%
# 👉 Write your code here

# %% [markdown]
# ## 💡 Extra utmaning
# - Filtrera och skriv ut kunder med saldo över 20 000
# - Beräkna det genomsnittliga saldot för alla kunder
# - Spara dictionaryn som `.json`-fil
