# %% [markdown]
# # 🏦 Bankkonto-system – OOP-övning i Python

# %% [markdown]
# ## 🎯 Objective
# Du ska skapa en klass som representerar ett **bankkonto**.
# Varje kund ska kunna:
# - öppna konto med namn och start-saldo
# - sätta in pengar
# - ta ut pengar
# - visa sitt saldo
#
# Målet är att förstå hur **klasser, objekt, attribut och metoder** fungerar i Python.

# %% [markdown]
# ## 🧩 Bakgrund
# En bank vill att du skapar en enkel Python-lösning för att hantera kundkonton digitalt.
# Du ska bygga en **klass** som fungerar som mall för varje kundkonto.
# Varje konto ska “komma ihåg” sitt eget saldo och kunna utföra transaktioner.

# %% [markdown]
# ## 🧠 Business Rules
#
# 1. Varje kund ska ha:
#    - ett **namn**
#    - ett **startsaldon** (standardvärde = 0 om inget anges)
#
# 2. Kunden ska kunna:
#    - **sätta in pengar** på kontot
#    - **ta ut pengar** (endast om det finns täckning)
#    - **visa sitt saldo**
#
# 3. Uttag ska inte tillåtas om pengarna inte räcker.
#    Då ska ett tydligt meddelande visas.
#
# 4. Systemet ska kunna hantera **flera kunder** (flera objekt av samma klass).

# %% [markdown]
# ## 🧱 Tekniska krav
#
# - Skapa en klass som heter `BankAccount`.
# - Använd `__init__` för att skapa kundens namn och saldo.
# - Skapa minst **tre metoder**:
#   1. En för insättning
#   2. En för uttag
#   3. En för att visa saldo

# %% [markdown]
# ## 📊 Testscenario (när klassen är klar)
#
# | Kund | Startsaldo | Åtgärd | Belopp | Förväntat resultat |
# |------|-------------|--------|--------|--------------------|
# | Marcus | 1000 | Sätt in | 500 | Nytt saldo 1500 |
# | Lisa | 500 | Ta ut | 600 | Ej tillräckligt saldo |
# | Marcus | - | Ta ut | 200 | Nytt saldo 1300 |
# | Marcus | - | Visa saldo | - | Saldot visas i konsolen |

# %% [markdown]
# ## 💻 Steg 1 – Skapa klassen

# %%
# YOUR CODE HERE

# %% [markdown]
# ## 💻 Steg 2 – Skapa objekt (kunder)

# %%
# YOUR CODE HERE

# %% [markdown]
# ## 💻 Steg 3 – Testa dina metoder

# %%
# YOUR CODE HERE

# %% [markdown]
# ## 🧩 Reflektion
#
# Svara i text (markdown):
#
# - Vad gör `__init__`-metoden?
# - Vad betyder `self` i metoderna?
# - Vad händer när du skapar flera objekt från samma klass?

# %%
# YOUR ANSWERS HERE

# %% [markdown]
# ## 🧠 Extra utmaning (valfri)
# Lägg till en metod som visar **kundens transaktionshistorik**, t.ex. varje insättning och uttag.

# %%
# YOUR CODE HERE
