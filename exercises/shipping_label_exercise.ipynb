# %% [markdown]
# # 🏷️ Exercise: Shipping Label Generator
# Learn how to use `*args` and `**kwargs` in Python by creating a flexible address label function.

# %% [markdown]
# ## 🎯 Goal
# Create a function that prints a complete **shipping label** using both positional (`*args`) and keyword (`**kwargs`) arguments.
#
# ---
#
# ### 🧩 Instructions
#
# 1. Define a function named `shipping_label()` that takes both `*args` and `**kwargs`.
# 2. The `*args` represent **name parts** (like title, first name, last name).
# 3. The `**kwargs` contain address details such as:
#    - `street`
#    - `apt` *(optional)*
#    - `pobox` *(optional)*
#    - `city`
#    - `state`
#    - `zip`
# 4. The function should print the label like this:
#    - All `*args` joined with spaces on one line.
#    - If `apt` exists → print `street` and `apt` on the same line.
#    - If `pobox` exists → print `street` and `pobox` on separate lines.
#    - Otherwise → print only `street`.
#    - Finally, print the city, state, and zip on one line.
# 5. Test your function with **three examples**:
#    - One with `apt`
#    - One with `pobox`
#    - One with neither
#
# ---
#
# ### 💡 Example Output
#
# ```python
# shipping_label("Dr.", "Kalle", "Albert", "III",
#                street="123 Fake St.",
#                apt="Apt #456",
#                city="Detroit",
#                state="MI",
#                zip="54321")
# ```
#
# Output:
# ```
# Dr. Kalle Albert III
# 123 Fake St. Apt #456
# Detroit MI, 54321
# ```

# %%
# TODO: Implement the function below



# --- Test your function below ---
# Example 1: with apt
# Example 2: with pobox
# Example 3: without apt/pobox

# %% [markdown]
# ---
# # ✅ Solution (scroll down when ready)
# *(Try solving above before revealing this part!)*
