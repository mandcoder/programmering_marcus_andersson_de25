# %% [markdown]
# ### läs in o manipulera data i ett dictionary

# %% [markdown]
# filen som skall användas heter order_lists.json

# %%
# Börja med att läsa in filen här

# %% [markdown]
# lista alla produkter i filen

# %% [markdown]
# Räkna ut den totala försäljningen för laptops

# %% [markdown]
# Count laptop sale per city

# %% [markdown]
# count tablet per city

# %% [markdown]
# #### show the 4 best city with highest revenue
