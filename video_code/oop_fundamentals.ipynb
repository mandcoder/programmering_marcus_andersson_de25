# %% [markdown]
# ### OOP fundamentals

# %%
class Admission:
    def __init__(self,school, program, name, accept):
        self.school = school
        self.progam = program
        self.name = name
        self.accepts = accept

person1 = Admission("cool school", "AI", accept=True, name="Kokchun")

person1

# %%
person1.name
# Out:
# 'Kokchun'

# %%
person1.name = "Bella"

# %%
person1.name
# Out:
# 'Bella'

# %%
person2 = Admission("cooler school", "Data engineering", accept=False, name="Gore Bord")
person2.progam, person1.progam
# Out:
# ('Data engineering', 'AI')

# %% [markdown]
# __ rep __  dunder ripper

# %%
class Admission:
    def __init__(self,school, program, name, accept):
        self.school = school
        self.program = program
        self.name = name
        self.accept = accept

    def __repr__(self):
        return f"Admission(school= '{self.school}', program = '{self.program}', name = '{self.name}', accept = {self.accept})"
    
student = Admission("Cool school", "Java", "Victor Freeze", True)
student
# Out:
# Admission(school= 'Cool school', program = 'Java', name = 'Victor Freeze', accept = True)

# %%
print(student)
# Out:
# Admission(school= 'Cool school', program = 'Java', name = 'Victor Freeze', accept = True)
